# %% [markdown]
# # Utilities

# %%
#Imports the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
#Defines the values for each of the five epochs for the various batch sizes
GPU64 = [15.87,16.03,15.6,16.09,15.43]
GPU64_2 = []
GPU64_3 = []
GPU128 = [19.56, 12.44, 12.61,12.56,12.67]
GPU128 = [20.84,13.81,13.49, 13.94,13.37]
GPU128 = [13.43,13.44, 13.46,13.63,13.66]
GPU256 = [18.47, 11.81,11.97,12.05,12.02]
GPU256_2 = []
GPU256_3 = []
GPU512 = [11.36,11.32,11.28,11.27,11.21]
GPU512_2 = []
GPU512_3 = []
GPU1024 = [11.32,11.29,11.13,11.25,11.24]
GPU1024_2 = []
GPU1024_3 = []

# %%
#Defines the values for each of the five epochs for the various batch sizes
CPU64 = [159.82,170.34,172.42,171.76,172.47]
CPU64_2 = []
CPU64_3 = []
CPU128 = [148.37, 154.09,155.4,155.37,155.69]
CPU128_2 = [152.66,161.34,170.43,174.63,177.92]
CPU128_3 = [183.66,181.61,177.66,178.33,180.16]
CPU256 = [184.68,179.36,180.68,190.11,182.42]
CPU256_2 = []
CPU256_3 = []
CPU512 = [196.21,175.1,186.65,176.78,178.89]
CPU512_2 = []
CPU512_3 = []
CPU1024 = [202.34, 208.97,204.3,200.68,216.68]
CPU1024_2 = []
CPU1024_3 = []

# %%
# create sample data and takes the mean of each previous defined list
data = {'Batch_Size': [64, 64, 128, 128, 256, 256, 512, 512, 1024, 1024],
        'Time': [np.mean(CPU64),np.mean(GPU64), np.mean(CPU128),np.mean(GPU128),np.mean(CPU256),np.mean(GPU256), np.mean(CPU512),np.mean(GPU512), np.mean(CPU1024),np.mean(GPU1024)],
        'Type': ['CPU', 'GPU','CPU', 'GPU','CPU', 'GPU','CPU', 'GPU','CPU','GPU']}
df = pd.DataFrame(data) #Adds the data to the main dataframe

df_cpu = df[df['Type'] == 'CPU']
df_gpu = df[df['Type'] == 'GPU']

# %% [markdown]
# # Data Visualization

# %%
# Defines the subplot
fig, ax = plt.subplots()
ax.set_xlabel('Batch Size')
ax.set_ylabel('Time(in seconds)')


#Plots the CPU and the GPU 
ax.plot(df_cpu['Batch_Size'], df_cpu['Time'], label='CPU',color='blue')
ax.plot(df_gpu['Batch_Size'], df_gpu['Time'], label='GPU', color='red')

#Adds the legend
ax.legend()

#Adds the title B
plt.title('CPU vs GPU Batch Size Comparison')

#Shows the plot 
plt.show()

#NOTE: Code and implementation of this graph is borrowed from CS: 5781 Machine Learning Engineering Module 3

# %%
# Defines the subplot
fig, ax = plt.subplots()
ax.set_xlabel('Batch Size')
ax.set_ylabel('Time(in seconds)')


#Plots the CPU and the GPU 
ax.plot(df_cpu['Batch_Size'], df_cpu['Time'], label='CPU',color='blue')
#ax.plot(df_gpu['Batch_Size'], df_gpu['Time'], label='GPU', color='red')

#Adds the legend
ax.legend()

#Adds the title 
plt.title('CPU Batch Size Comparison')

#Shows the plot 
plt.show()

#NOTE: Code and implementation of this graph is borrowed from CS: 5781 Machine Learning Engineering Module 3

# %%
# Defines the subplot
fig, ax = plt.subplots()
ax.set_xlabel('Batch Size')
ax.set_ylabel('Time(in seconds)')


#Plots the CPU and the GPU 
#ax.plot(df_cpu['Batch_Size'], df_cpu['Time'], label='CPU',color='blue')
ax.plot(df_gpu['Batch_Size'], df_gpu['Time'], label='GPU', color='red')

#Adds the legend
ax.legend()

#Adds the title 
plt.title('GPU Batch Size Comparison')

#Shows the plot 
plt.show()

#NOTE: Code and implementation of this graph is borrowed from CS: 5781 Machine Learning Engineering Module 3

# %%
#Defines the values for each of the five epochs for the various batch sizes
GPU1 = [20.84,13.81,13.49, 13.94,13.37]
GPU2 = [13.43,13.44, 13.46,13.63,13.66]
GPU3 = [13.44,13.26,13.53,13.5,13.47]
GPU4 = [13.51,13.62,13.57,13.36,13.46]
GPU5 = [13.61,13.31,13.77,13.32,13.65]

GPU_128_avg = [np.mean(GPU1),np.mean(GPU2),np.mean(GPU3),np.mean(GPU4),np.mean(GPU5)]
GPU_128_1 = [GPU1[0],GPU2[0],GPU3[0],GPU4[0],GPU5[0]]
GPU_128_2 = [GPU1[1],GPU2[1],GPU3[1],GPU4[1],GPU5[1]]
GPU_128_3 = [GPU1[2],GPU2[2],GPU3[2],GPU4[2],GPU5[2]]
GPU_128_4 = [GPU1[3],GPU2[3],GPU3[3],GPU4[3],GPU5[3]]
GPU_128_5 = [GPU1[4],GPU2[4],GPU3[4],GPU4[4],GPU5[4]]

# %%
def summary_stats(data):
    return (np.min(data),np.max(data),np.median(data),np.mean(data),np.std(data))

# %%
summary_stats(GPU_128_5)
# Out:
# (13.37, 13.66, 13.47, 13.522, 0.11408768557561345)

# %%
print(np.std(GPU_128_1))
print(np.mean(GPU_128_1))
print(np.std(GPU_128_2))
print(np.mean(GPU_128_2))
print(np.std(GPU_128_3))
print(np.mean(GPU_128_3))
print(np.std(GPU_128_4))
print(np.mean(GPU_128_4))
print(np.std(GPU_128_5))
print(np.mean(GPU_128_5))
print(np.std(GPU_128_avg))
print(np.mean(GPU_128_avg))
# Out:
# 2.937703865266205
# 14.965999999999998
# 0.20350921355064006
# 13.488
# 0.10947145746723176
# 13.564000000000002
# 0.2236067977499789
# 13.55
# 0.11408768557561345
# 13.522
# 0.6368195976883873
# 13.818000000000001

# %%
# create sample data and takes the mean of each previous defined list
data = {'Epoch': ['Epoch 1','Epoch 1','Epoch 1','Epoch 1','Epoch 1','Epoch 2','Epoch 2','Epoch 2','Epoch 2','Epoch 2','Epoch 3','Epoch 3','Epoch 3','Epoch 3','Epoch 3','Epoch 4','Epoch 4','Epoch 4','Epoch 4','Epoch 4','Epoch 5','Epoch 5','Epoch 5','Epoch 5','Epoch 5'],
        'Time': [20.84,13.43,13.44,13.51,13.61,13.81,13.44,13.26,13.62,13.31,13.49,13.46,13.53,13.57,13.77,13.94,13.63,13.5,13.36,13.32,13.37,13.66,13.47,13.46,13.65],
        'Type': ['Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5',]}
df = pd.DataFrame(data) #Adds the data to the main dataframe

df_trial_1= df[df['Type'] == 'Trial 1']
df_trial_2 = df[df['Type'] == 'Trial 2']
df_trial_3 = df[df['Type'] == 'Trial 3']
df_trial_4 = df[df['Type'] == 'Trial 4']
df_trial_5 = df[df['Type'] == 'Trial 5']


# Defines the subplot
fig, ax = plt.subplots()
ax.set_xlabel('Epoch')
ax.set_ylabel('Time(in seconds)')


#Plots the CPU and the GPU 
ax.plot(df_trial_1['Epoch'], df_trial_1['Time'], label='Trial 1',color='blue')
ax.plot(df_trial_2['Epoch'], df_trial_2['Time'], label='Trial 2',color='red')
ax.plot(df_trial_3['Epoch'], df_trial_3['Time'], label='Trial 3',color='black')
ax.plot(df_trial_4['Epoch'], df_trial_4['Time'], label='Trial 4',color='orange')
ax.plot(df_trial_5['Epoch'], df_trial_5['Time'], label='Trial 5',color='green')

#Adds the legend
ax.legend()

#Adds the title 
plt.title('Time Comparison by Epoch for GPU')

#Shows the plot 
plt.show()

#NOTE: Code and implementation of this graph is borrowed from CS: 5781 Machine Learning Engineering Module 3

# %%
#Defines the values for each of the five epochs for the various batch sizes
CPU1 = [152.66,161.34,170.43,174.63,177.92]
CPU2 = [183.66,181.61,177.66,178.33,180.16]
CPU3 = [174.93,177.25,176.25,174.75,175.66]
CPU4 = [168.44,171.48,171.89,180.99,174.44]
CPU5 = [171.37,172.89,172.69,171.01,172.49]


CPU_128_avg = [np.mean(CPU1),np.mean(CPU2),np.mean(CPU3),np.mean(CPU4),np.mean(CPU5)]
CPU_128_1 = [CPU1[0],CPU2[0],CPU3[0],CPU4[0],CPU5[0]]
CPU_128_2 = [CPU1[1],CPU2[1],CPU3[1],CPU4[1],CPU5[1]]
CPU_128_3 = [CPU1[2],CPU2[2],CPU3[2],CPU4[2],CPU5[2]]
CPU_128_4 = [CPU1[3],CPU2[3],CPU3[3],CPU4[3],CPU5[3]]
CPU_128_5 = [CPU1[4],CPU2[4],CPU3[4],CPU4[4],CPU5[4]]

# %%
print(np.std(CPU_128_1))
print(np.mean(CPU_128_1))
print(np.std(CPU_128_2))
print(np.mean(CPU_128_2))
print(np.std(CPU_128_3))
print(np.mean(CPU_128_3))
print(np.std(CPU_128_4))
print(np.mean(CPU_128_4))
print(np.std(CPU_128_5))
print(np.mean(CPU_128_5))
print(np.std(CPU_128_avg))
print(np.mean(CPU_128_avg))
# Out:
# 10.155411168436265
# 170.21200000000002
# 6.78875128429375
# 172.91400000000002
# 2.7253594258372593
# 173.78400000000002
# 3.424957809959132
# 175.942
# 2.6747530727153066
# 176.13400000000001
# 4.2420386796916425
# 173.7972

# %%
summary_stats(CPU_128_5)
# Out:
# (172.49, 180.16, 175.66, 176.13400000000001, 2.6747530727153066)

# %%
# create sample data and takes the mean of each previous defined list
data = {'Epoch': ['Epoch 1','Epoch 1','Epoch 1','Epoch 1','Epoch 1','Epoch 2','Epoch 2','Epoch 2','Epoch 2','Epoch 2','Epoch 3','Epoch 3','Epoch 3','Epoch 3','Epoch 3','Epoch 4','Epoch 4','Epoch 4','Epoch 4','Epoch 4','Epoch 5','Epoch 5','Epoch 5','Epoch 5','Epoch 5'],
        'Time': [152.66,183.66, 174.93,168.44,171.37,161.34,181.61,177.25,171.48, 172.89,170.43,177.66, 176.25,171.89,172.69,174.63,178.33,174.75,180.99,171.01,177.92,180.16, 175.66,174.44,172.49 ],
        'Type': ['Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5','Trial 1','Trial 2','Trial 3', 'Trial 4', 'Trial 5',]}
df = pd.DataFrame(data) #Adds the data to the main dataframe

df_trial_1= df[df['Type'] == 'Trial 1']
df_trial_2 = df[df['Type'] == 'Trial 2']
df_trial_3 = df[df['Type'] == 'Trial 3']
df_trial_4 = df[df['Type'] == 'Trial 4']
df_trial_5 = df[df['Type'] == 'Trial 5']


# Defines the subplot
fig, ax = plt.subplots()
ax.set_xlabel('Epoch')
ax.set_ylabel('Time(in seconds)')


#Plots the CPU and the GPU 
ax.plot(df_trial_1['Epoch'], df_trial_1['Time'], label='Trial 1',color='blue')
ax.plot(df_trial_2['Epoch'], df_trial_2['Time'], label='Trial 2',color='red')
ax.plot(df_trial_3['Epoch'], df_trial_3['Time'], label='Trial 3',color='black')
ax.plot(df_trial_4['Epoch'], df_trial_4['Time'], label='Trial 4',color='orange')
ax.plot(df_trial_5['Epoch'], df_trial_5['Time'], label='Trial 5',color='green')

#Adds the legend
ax.legend()

#Adds the title 
plt.title('Time Comparison by Epoch for CPU')

#Shows the plot 
plt.show()

#NOTE: Code and implementation of this graph is borrowed from CS: 5781 Machine Learning Engineering Module 3

# %%
summary_stats(df_cpu['Time'])
# Out:
# (153.78400000000002, 206.594, 182.726, 179.1832, 17.456713899242313)

# %%
summary_stats(df_gpu['Time'])
# Out:
# (11.246, 15.804000000000002, 13.264, 13.025199999999998, 1.6858809447882142)
